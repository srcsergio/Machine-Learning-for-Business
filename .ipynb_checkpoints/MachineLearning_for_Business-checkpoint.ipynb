# %%
#%matplotlib widget
#!pip install matplotlib
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('Metro_Interstate_Traffic_Volume.csv')

df.head()
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0     NaN  288.28      0.0      0.0          40       Clouds
# 1     NaN  289.36      0.0      0.0          75       Clouds
# 2     NaN  289.58      0.0      0.0          90       Clouds
# 3     NaN  290.13      0.0      0.0          90       Clouds
# 4     NaN  291.14      0.0      0.0          75       Clouds
#
#   weather_description            date_time  traffic_volume
# 0    scattered clouds  2012-10-02 09:00:00            5545
# 1       broken clouds  2012-10-02 10:00:00            4516
# 2     overcast clouds  2012-10-02 11:00:00            4767
# 3     overcast clouds  2012-10-02 12:00:00            5026
# 4       broken clouds  2012-10-02 13:00:00            4918

# %%
df.tail()
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 48199     NaN  283.45      0.0      0.0          75        Clouds
# 48200     NaN  282.76      0.0      0.0          90        Clouds
# 48201     NaN  282.73      0.0      0.0          90  Thunderstorm
# 48202     NaN  282.09      0.0      0.0          90        Clouds
# 48203     NaN  282.12      0.0      0.0          90        Clouds
#
#           weather_description            date_time  traffic_volume
# 48199           broken clouds  2018-09-30 19:00:00            3543
# 48200         overcast clouds  2018-09-30 20:00:00            2781
# 48201  proximity thunderstorm  2018-09-30 21:00:00            2159
# 48202         overcast clouds  2018-09-30 22:00:00            1450
# 48203         overcast clouds  2018-09-30 23:00:00             954

# %% [markdown]
# ### Let's first perform an Exploratory Data Analysis.

# %% [markdown]
# > _Lets look at the shape of dataset, to see the total number of rows(records) and columns_

# %%
df.shape
# Out:
# (48204, 9)

# %% [markdown]
# > _Let's get the number of elements in our dataset_

# %%
df.size
# Out:
# 433836

# %% [markdown]
# > _Lets look at data type, to analyze whether any type of conversion needs to be performed_

# %%
df.dtypes
# Out:
# holiday                 object
# temp                   float64
# rain_1h                float64
# snow_1h                float64
# clouds_all               int64
# weather_main            object
# weather_description     object
# date_time               object
# traffic_volume           int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48204 entries, 0 to 48203
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   holiday              61 non-null     object
#  1   temp                 48204 non-null  float64
#  2   rain_1h              48204 non-null  float64
#  3   snow_1h              48204 non-null  float64
#  4   clouds_all           48204 non-null  int64
#  5   weather_main         48204 non-null  object
#  6   weather_description  48204 non-null  object
#  7   date_time            48204 non-null  object
#  8   traffic_volume       48204 non-null  int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 3.3+ MB

# %% [markdown]
# > _As we can see, our column date_time is an object. For this column, which we will use for time series, we need to convert it into the correct data type(datetime64)._

# %%
df['date_time'] = pd.to_datetime(df['date_time'])
df['date_time']
# Out:
# 0       2012-10-02 09:00:00
# 1       2012-10-02 10:00:00
# 2       2012-10-02 11:00:00
# 3       2012-10-02 12:00:00
# 4       2012-10-02 13:00:00
#                 ...
# 48199   2018-09-30 19:00:00
# 48200   2018-09-30 20:00:00
# 48201   2018-09-30 21:00:00
# 48202   2018-09-30 22:00:00
# 48203   2018-09-30 23:00:00
# Name: date_time, Length: 48204, dtype: datetime64[ns]

# %% [markdown]
# > _Let's examine the information in general to get an idea of how the data is presented._

# %%
df.head(10).transpose()
# Out:
#                                        0                    1  \
# holiday                              NaN                  NaN
# temp                              288.28               289.36
# rain_1h                              0.0                  0.0
# snow_1h                              0.0                  0.0
# clouds_all                            40                   75
# weather_main                      Clouds               Clouds
# weather_description     scattered clouds        broken clouds
# date_time            2012-10-02 09:00:00  2012-10-02 10:00:00
# traffic_volume                      5545                 4516
#
#                                        2                    3  \
# holiday                              NaN                  NaN
# temp                              289.58               290.13
# rain_1h                              0.0                  0.0
# snow_1h                              0.0                  0.0
# clouds_all                            90                   90
# weather_main                      Clouds               Clouds
# weather_description      overcast clouds      overcast clouds
# date_time            2012-10-02 11:00:00  2012-10-02 12:00:00
# traffic_volume                      4767                 5026
#
#                                        4                    5  \
# holiday                              NaN                  NaN
# temp                              291.14               291.72
# rain_1h                              0.0                  0.0
# snow_1h                              0.0                  0.0
# clouds_all                            75                    1
# weather_main                      Clouds                Clear
# weather_description        broken clouds         sky is clear
# date_time            2012-10-02 13:00:00  2012-10-02 14:00:00
# traffic_volume                      4918                 5181
#
#                                        6                    7  \
# holiday                              NaN                  NaN
# temp                              293.17               293.86
# rain_1h                              0.0                  0.0
# snow_1h                              0.0                  0.0
# clouds_all                             1                    1
# weather_main                       Clear                Clear
# weather_description         sky is clear         sky is clear
# date_time            2012-10-02 15:00:00  2012-10-02 16:00:00
# traffic_volume                      5584                 6015
#
#                                        8                    9
# holiday                              NaN                  NaN
# temp                              294.14                293.1
# rain_1h                              0.0                  0.0
# snow_1h                              0.0                  0.0
# clouds_all                            20                   20
# weather_main                      Clouds               Clouds
# weather_description           few clouds           few clouds
# date_time            2012-10-02 17:00:00  2012-10-02 18:00:00
# traffic_volume                      5791                 4770

# %% [markdown]
# > _Looking at the holiday column, it appears we have several rows with empty values. Although this is currently an irrelevant column, let's check them all._

# %%
df.isna().sum()
# Out:
# holiday                48143
# temp                       0
# rain_1h                    0
# snow_1h                    0
# clouds_all                 0
# weather_main               0
# weather_description        0
# date_time                  0
# traffic_volume             0
# dtype: int64

# %% [markdown]
# > _We'll check for duplicate values, and if any are found, we'll delete them if there are not too many._

# %%
duplicates = df[df.duplicated()]

duplicates
# Out:
#       holiday     temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 18697     NaN  286.290      0.0      0.0           1         Clear
# 23851     NaN  289.060      0.0      0.0          90        Clouds
# 26784     NaN  289.775      0.0      0.0          56        Clouds
# 26980     NaN  287.860      0.0      0.0           0         Clear
# 27171     NaN  279.287      0.0      0.0          56        Clouds
# 28879     NaN  267.890      0.0      0.0          90          Snow
# 29268     NaN  254.220      0.0      0.0           1         Clear
# 34711     NaN  295.010      0.0      0.0          40        Clouds
# 34967     NaN  292.840      0.0      0.0           1         Clear
# 34969     NaN  294.520      0.0      0.0           1         Clear
# 34971     NaN  295.770      0.0      0.0          75        Clouds
# 34973     NaN  296.950      0.0      0.0           1  Thunderstorm
# 37572     NaN  288.890      0.0      0.0           1         Clear
# 38676     NaN  278.720      0.0      0.0          90       Drizzle
# 38677     NaN  278.720      0.0      0.0          90          Mist
# 39527     NaN  266.220      0.0      0.0           1         Clear
# 48173     NaN  280.680      0.0      0.0          90        Clouds
#
#            weather_description           date_time  traffic_volume
# 18697             sky is clear 2015-09-30 19:00:00            3679
# 23851          overcast clouds 2016-06-01 10:00:00            4831
# 26784            broken clouds 2016-09-21 15:00:00            5365
# 26980             Sky is Clear 2016-09-29 19:00:00            3435
# 27171            broken clouds 2016-10-07 18:00:00            4642
# 28879               light snow 2016-12-06 18:00:00            4520
# 29268             sky is clear 2016-12-19 00:00:00             420
# 34711         scattered clouds 2017-06-21 11:00:00            4808
# 34967             sky is clear 2017-06-30 10:00:00            4638
# 34969             sky is clear 2017-06-30 11:00:00            4725
# 34971            broken clouds 2017-06-30 12:00:00            5229
# 34973             thunderstorm 2017-06-30 13:00:00            5263
# 37572             sky is clear 2017-09-29 19:00:00            4498
# 38676  light intensity drizzle 2017-11-05 01:00:00             629
# 38677                     mist 2017-11-05 01:00:00             629
# 39527             sky is clear 2017-12-05 18:00:00            3936
# 48173          overcast clouds 2018-09-29 19:00:00            3818

# %%
# check how many rows are duplicated
duplicates.shape
# Out:
# (17, 9)

# %%
# remove duplicated rows
df = df.drop_duplicates()

# %% [markdown]
# > _Let's examine some descriptive statistics to understand the characteristics of our dataset._

# %%
df.describe().transpose()
# Out:
#                   count                           mean                  min  \
# temp            48187.0                     281.204995                  0.0
# rain_1h         48187.0                       0.334382                  0.0
# snow_1h         48187.0                       0.000222                  0.0
# clouds_all      48187.0                      49.365451                  0.0
# date_time         48187  2016-01-05 06:49:48.133729024  2012-10-02 09:00:00
# traffic_volume  48187.0                    3259.618134                  0.0
#
#                                 25%                  50%                  75%  \
# temp                         272.16               282.45              291.806
# rain_1h                         0.0                  0.0                  0.0
# snow_1h                         0.0                  0.0                  0.0
# clouds_all                      1.0                 64.0                 90.0
# date_time       2014-02-06 07:30:00  2016-06-10 21:00:00  2017-08-11 05:30:00
# traffic_volume               1192.5               3379.0               4933.0
#
#                                 max          std
# temp                         310.07    13.338738
# rain_1h                      9831.3    44.797033
# snow_1h                        0.51     0.008169
# clouds_all                    100.0    39.015213
# date_time       2018-09-30 23:00:00          NaN
# traffic_volume               7280.0  1986.954465

# %% [markdown]
# > _Let's plot a graph to see if we have any outliers._

# %%
sns.boxplot(data=df['traffic_volume']);

# %% [markdown]
# ### Forecasting

# %%
df_clean = df[['date_time', 'traffic_volume']]

df_clean.head()
# Out:
#             date_time  traffic_volume
# 0 2012-10-02 09:00:00            5545
# 1 2012-10-02 10:00:00            4516
# 2 2012-10-02 11:00:00            4767
# 3 2012-10-02 12:00:00            5026
# 4 2012-10-02 13:00:00            4918

# %%
df_clean = df_clean.set_index('date_time')

df_clean.head()
# Out:
#                      traffic_volume
# date_time
# 2012-10-02 09:00:00            5545
# 2012-10-02 10:00:00            4516
# 2012-10-02 11:00:00            4767
# 2012-10-02 12:00:00            5026
# 2012-10-02 13:00:00            4918

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot(df_clean['traffic_volume'])
ax.set_xlabel('Time')
ax.set_ylabel('traffic_volume')

fig.autofmt_xdate()

plt.tight_layout()

# %% [markdown]
# > _When plotting our first graph, we noticed a lack of data for the year 2015; this could negatively affect our predictions. Let's select only the last 3 years, 2016, 2017, 2018. Even so, we will have enough data for our prediction._

# %%
filtered_2015 = df.loc[(df['date_time'] > '2015-01-01') & (df['date_time'] < '2016-01-01')]

filtered_2015.head()
# Out:
#       holiday     temp  rain_1h  snow_1h  clouds_all weather_main  \
# 15971     NaN  287.586      0.0      0.0          92         Rain
# 15972     NaN  297.543      0.0      0.0           0        Clear
# 15973     NaN  292.061      0.0      0.0           8        Clear
# 15974     NaN  292.061      0.0      0.0           8        Clear
# 15975     NaN  294.840      0.0      0.0          76       Clouds
#
#       weather_description           date_time  traffic_volume
# 15971          light rain 2015-06-11 20:00:00            2886
# 15972        Sky is Clear 2015-06-12 18:00:00            4380
# 15973        sky is clear 2015-06-12 20:00:00            3095
# 15974        sky is clear 2015-06-12 21:00:00            3299
# 15975       broken clouds 2015-06-13 21:00:00            3040

# %%
filtered_2015.tail()
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 20339     NaN  264.83      0.0      0.0          90         Snow
# 20340     NaN  264.89      0.0      0.0          90         Snow
# 20341     NaN  265.32      0.0      0.0          90         Snow
# 20342     NaN  265.51      0.0      0.0          75         Snow
# 20343     NaN  265.78      0.0      0.0          75         Snow
#
#       weather_description           date_time  traffic_volume
# 20339          light snow 2015-12-31 15:00:00            5747
# 20340          light snow 2015-12-31 16:00:00            5467
# 20341          light snow 2015-12-31 19:00:00            3576
# 20342          light snow 2015-12-31 21:00:00            2768
# 20343          light snow 2015-12-31 23:00:00            1802

# %% [markdown]
# > _There are 6 months of unrecorded data missing._

# %%
dataFrame_filtered = df.loc[(df['date_time'] > '2015-12-31 23:00:00	')]

dataFrame_filtered.head()
# Out:
#              holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 20344  New Years Day  265.94      0.0      0.0          90         Haze
# 20345  New Years Day  265.94      0.0      0.0          90         Snow
# 20346            NaN  266.00      0.0      0.0          90         Snow
# 20347            NaN  266.01      0.0      0.0          90         Snow
# 20348            NaN  264.80      0.0      0.0          90       Clouds
#
#       weather_description           date_time  traffic_volume
# 20344                haze 2016-01-01 00:00:00            1513
# 20345          light snow 2016-01-01 00:00:00            1513
# 20346          light snow 2016-01-01 01:00:00            1550
# 20347          light snow 2016-01-01 03:00:00             719
# 20348     overcast clouds 2016-01-01 04:00:00             533

# %%
dataFrame_filtered.tail()
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 48199     NaN  283.45      0.0      0.0          75        Clouds
# 48200     NaN  282.76      0.0      0.0          90        Clouds
# 48201     NaN  282.73      0.0      0.0          90  Thunderstorm
# 48202     NaN  282.09      0.0      0.0          90        Clouds
# 48203     NaN  282.12      0.0      0.0          90        Clouds
#
#           weather_description           date_time  traffic_volume
# 48199           broken clouds 2018-09-30 19:00:00            3543
# 48200         overcast clouds 2018-09-30 20:00:00            2781
# 48201  proximity thunderstorm 2018-09-30 21:00:00            2159
# 48202         overcast clouds 2018-09-30 22:00:00            1450
# 48203         overcast clouds 2018-09-30 23:00:00             954

# %%
df_clean = dataFrame_filtered.drop_duplicates(subset='date_time', keep="last")

df_clean.head()
# Out:
#              holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 20345  New Years Day  265.94      0.0      0.0          90         Snow
# 20346            NaN  266.00      0.0      0.0          90         Snow
# 20347            NaN  266.01      0.0      0.0          90         Snow
# 20348            NaN  264.80      0.0      0.0          90       Clouds
# 20349            NaN  264.38      0.0      0.0          90       Clouds
#
#       weather_description           date_time  traffic_volume
# 20345          light snow 2016-01-01 00:00:00            1513
# 20346          light snow 2016-01-01 01:00:00            1550
# 20347          light snow 2016-01-01 03:00:00             719
# 20348     overcast clouds 2016-01-01 04:00:00             533
# 20349     overcast clouds 2016-01-01 05:00:00             586

# %%
df_clean.tail()
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 48199     NaN  283.45      0.0      0.0          75        Clouds
# 48200     NaN  282.76      0.0      0.0          90        Clouds
# 48201     NaN  282.73      0.0      0.0          90  Thunderstorm
# 48202     NaN  282.09      0.0      0.0          90        Clouds
# 48203     NaN  282.12      0.0      0.0          90        Clouds
#
#           weather_description           date_time  traffic_volume
# 48199           broken clouds 2018-09-30 19:00:00            3543
# 48200         overcast clouds 2018-09-30 20:00:00            2781
# 48201  proximity thunderstorm 2018-09-30 21:00:00            2159
# 48202         overcast clouds 2018-09-30 22:00:00            1450
# 48203         overcast clouds 2018-09-30 23:00:00             954

# %%
df_clean = df_clean[['date_time', 'traffic_volume']]

df_sample = df_clean[['date_time', 'traffic_volume']]

df_clean.head()
# Out:
#                 date_time  traffic_volume
# 20345 2016-01-01 00:00:00            1513
# 20346 2016-01-01 01:00:00            1550
# 20347 2016-01-01 03:00:00             719
# 20348 2016-01-01 04:00:00             533
# 20349 2016-01-01 05:00:00             586

# %%
df_clean.shape
# Out:
# (23084, 2)

# %%
df_clean = df_clean.set_index('date_time')

df_clean.head()
# Out:
#                      traffic_volume
# date_time
# 2016-01-01 00:00:00            1513
# 2016-01-01 01:00:00            1550
# 2016-01-01 03:00:00             719
# 2016-01-01 04:00:00             533
# 2016-01-01 05:00:00             586

# %%
fig, ax = plt.subplots()
ax.plot(df_clean['traffic_volume'])
ax.set_xlabel('Time')
ax.set_ylabel('traffic_volume')

fig.autofmt_xdate()

plt.tight_layout()

# %% [markdown]
# > _Since we have 23,000 hourly samples, the graph is difficult to interpret. We will resample the data by monthly to see if we can gather more information._

# %%
monthly = df_clean.resample('M').sum()
monthly.plot(style=['-'])
plt.ylabel('Monthly Traffic');

# %%
monthly.head()
# Out:
#             traffic_volume
# date_time
# 2016-01-31         1387843
# 2016-02-29         1626991
# 2016-03-31         1604805
# 2016-04-30         2091544
# 2016-05-31         2396927

# %% [markdown]
# > _It appears the series isn't stationary, as it shows a growth trend followed by a decline, then a rise again, and then a stable trend. and it seems to have a seasonality._

# %%
from statsmodels.tsa.stattools import adfuller

ADF = adfuller(monthly)
print(f'ADF Statistic: {ADF[0]}')
print(f'p-value: {ADF[1]}')
# Out:
# ADF Statistic: -2.6573462620390553
# p-value: 0.08171448516187402

# %% [markdown]
# > _For a series to be stationary, the ADF statistic must be a large negative number, and the p-value must be less than 0.05. The result don't meets the requirements. Therefore, our series is no-stationary._

# %% [markdown]
# > _Okay, but we used a monthly sample; let's take a small interval from the original dataset and check again._

# %%
df_small_interval = df_clean[['traffic_volume']]['2017-01-01 00:00:00':'2017-01-31 23:00:00']

# %%
df_small_interval.head()
# Out:
#                      traffic_volume
# date_time
# 2017-01-01 00:00:00            1848
# 2017-01-01 01:00:00            1806
# 2017-01-01 02:00:00            1211
# 2017-01-01 03:00:00             794
# 2017-01-01 04:00:00             500

# %%
df_small_interval.shape
# Out:
# (744, 1)

# %%
fig, ax = plt.subplots()
ax.plot(df_small_interval['traffic_volume'])
ax.set_xlabel('Time')
ax.set_ylabel('traffic_volume')

fig.autofmt_xdate()

plt.tight_layout()

# %%
ADF = adfuller(df_small_interval)
print(f'ADF Statistic: {ADF[0]}')
print(f'p-value: {ADF[1]}')
# Out:
# ADF Statistic: -3.8123680948441456
# p-value: 0.002783278053618337

# %% [markdown]
# > _Looking at the graph and analyzing the values ​​of ADF (negative value) and p-value (< 0.05), it appears that our series is stationary._

# %%
df_clean.head()
# Out:
#                      traffic_volume
# date_time
# 2016-01-01 00:00:00            1513
# 2016-01-01 01:00:00            1550
# 2016-01-01 03:00:00             719
# 2016-01-01 04:00:00             533
# 2016-01-01 05:00:00             586

# %% [markdown]
# > _We will apply ADF to the complete dataset and plot ACF and PACF to analyze and obtain more information._

# %%
ADF = adfuller(df_clean)
print(f'ADF Statistic: {ADF[0]}')
print(f'p-value: {ADF[1]}')
# Out:
# ADF Statistic: -19.293283303079694
# p-value: 0.0

# %% [markdown]
#  > _With a large negative ADF statistic of -19.29 and a p-value of 0.0, which is smaller than 0.05, we can conclude that our series is stationary._

# %%
from statsmodels.graphics.tsaplots import plot_acf

plot_acf(df_clean.squeeze(), lags=40);

# %% [markdown]
# > _It appears that our data is seasonal, as the ACF chart displays cyclical patterns._

# %%
from statsmodels.graphics.tsaplots import plot_pacf

plot_pacf(df_clean, lags=30);

# %% [markdown]
# > _So far, both graphs exhibit a sinusoidal pattern, providing little information. Both the ACF and PACF plots fail to show a clear boundary between significant and non-significant coefficients. Therefore we may be looking at an ARMA pattern - autoregressive moving average._

# %%
df_sample = df_sample.tail(10000)

# %%
df_sample.head()
# Out:
#                 date_time  traffic_volume
# 36069 2017-08-09 00:00:00             676
# 36070 2017-08-09 01:00:00             395
# 36071 2017-08-09 02:00:00             306
# 36072 2017-08-09 03:00:00             381
# 36073 2017-08-09 04:00:00             949

# %%
df_sample.tail()
# Out:
#                 date_time  traffic_volume
# 48199 2018-09-30 19:00:00            3543
# 48200 2018-09-30 20:00:00            2781
# 48201 2018-09-30 21:00:00            2159
# 48202 2018-09-30 22:00:00            1450
# 48203 2018-09-30 23:00:00             954

# %%
df_sample.shape
# Out:
# (10000, 2)

# %%
df_sample = df_sample.reset_index(drop=True)

# %%
df_sample.head()
# Out:
#             date_time  traffic_volume
# 0 2017-08-09 00:00:00             676
# 1 2017-08-09 01:00:00             395
# 2 2017-08-09 02:00:00             306
# 3 2017-08-09 03:00:00             381
# 4 2017-08-09 04:00:00             949

# %%
df_sample.tail()
# Out:
#                date_time  traffic_volume
# 9995 2018-09-30 19:00:00            3543
# 9996 2018-09-30 20:00:00            2781
# 9997 2018-09-30 21:00:00            2159
# 9998 2018-09-30 22:00:00            1450
# 9999 2018-09-30 23:00:00             954

# %% [markdown]
# > _Let's separate our data into training and testing sets. Since our data is separated by hours and we need to predict traffic every hour for the next two weeks, we have a total of 2 weeks, which equals 336 hours. We decided to use a smaller sample for better understanding._

# %%
#df_sample = df_sample.set_index('date_time')
train = df_sample[['traffic_volume']][:-336]

test = df_sample[['traffic_volume']][-336:] # there are 336 hours in two week 

print(len(train))
print(len(test))

train.head()
# Out:
# 9664
# 336
#    traffic_volume
# 0             676
# 1             395
# 2             306
# 3             381
# 4             949

# %% [markdown]
# > _Let's visualize our train set and test set_

# %%
fig, ax = plt.subplots(figsize=(10, 8))

ax.plot(df_sample['traffic_volume'])
ax.set_xlabel('Traffic Volume')
ax.set_ylabel('Hourly Traffic')
ax.axvspan(9664, 10000, color='#808080', alpha=0.2)

plt.xticks(np.arange(0, 10000, 730),['Aug 2017', 'Sep', 'Oct', 'Nov', 'Dec', '2018', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep'])

fig.autofmt_xdate()
plt.tight_layout()

# %% [markdown]
# > _Le's use a function to fit different ARMA(p,q) models and compute the AIC result for select the best model_

# %%
from typing import Union
from statsmodels.tsa.statespace.sarimax import SARIMAX

def ARMA(endog: Union[pd.Series, list], order_list: list) -> pd.DataFrame:

    results = []
    for order in (order_list):
        
            model = SARIMAX(endog, order=(order[0], 0, order[1]), simple_differencing=False).fit(disp=False)
            aic = model.aic
            results.append([order, aic])
        
    result_df = pd.DataFrame(results)
    result_df.columns = ['(p,q)', 'AIC']

    #Sort in ascending order
    result_df = result_df.sort_values(by='AIC', ascending=True).reset_index(drop=True)
    return result_df

# %%
import warnings
warnings.filterwarnings('ignore')

from itertools import product

p = range(0, 4, 1)
q = range(0, 4, 1)

order_list = list(product(p, q))

result_df = ARMA(train['traffic_volume'], order_list)
result_df

# %% [markdown]
# >_Looking at the resulting dataframe, we can see that the model with the lowest AIC indicates that the model to be selected is ARMA(3,3)._

# %%
model = SARIMAX(train['traffic_volume'], order=(3,0,3), simple_differencing=False)

model_fit = model.fit(disp=False)

print(model_fit.summary())

# %% [markdown]
# >_Now let's analyze what the Q-Q plot, as well as the other plots, tells us._

# %%
model_fit.plot_diagnostics(figsize=(10, 8));

# %% [markdown]
# > _Looking at the graphs, it seems we have a normal distribution. The Q-Q plot shows that  is very close to y=x in some parts, but it appears that the ACF plot is still showing some autocorrelation afterlag 0._

# %%
from statsmodels.stats.diagnostic import acorr_ljungbox

residuals = model_fit.resid


pvalue = acorr_ljungbox(residuals, np.arange(1, 11, 1))['lb_pvalue']

print(pvalue)

# %% [markdown]
# >_Since the returned values ​​are not greater than 0.05, we cannot conclude that our residuals are in fact uncorrelated. Even so, let's try to make a Forecasting._

# %%
def ARMA_forecast(df: pd.DataFrame, train_len: int, horizon: int, window: int) -> list:

    total_len = train_len + horizon
    end_idx = train_len
    ARMA = []
        
    for i in range(train_len, total_len, window):
        model = SARIMAX(df[:i], order=(3,0,3))
        res = model.fit(disp=False)
        predictions = res.get_prediction(0, i + window - 1)
        oos_pred = predictions.predicted_mean.iloc[-window:]
        ARMA.extend(oos_pred)
    return ARMA

# %%
df_sample.head()

# %%
df_pred = df_sample[['traffic_volume']]

df_pred.head()

# %%
TRAIN_LEN = len(train)
HORIZON = len(test)
WINDOW = 3

pred_ARMA = ARMA_forecast(df_pred, TRAIN_LEN, HORIZON, WINDOW)


test.loc[:, 'pred_ARMA'] = pred_ARMA
test.head()

# %%
fig, ax = plt.subplots(figsize=(10, 8))

ax.plot(df_sample['traffic_volume'])
ax.plot(test['traffic_volume'], 'b-', label='actual')
ax.plot(test['pred_ARMA'], 'r--', label='ARMA(3,9)')

ax.legend(loc=2)

ax.set_xlabel('Traffic Volume')
ax.set_ylabel('Hourly Traffic')

ax.axvspan(9664, 9999, color='#808080', alpha=0.2)

ax.set_xlim(9800, 9999) # Zom in on the test period

plt.xticks(np.arange(0, 10000, 730),['Aug 2017', 'Sep', 'Oct', 'Nov', 'Dec', '2018', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep'])

fig.autofmt_xdate()
plt.tight_layout()

# %% [markdown]
# > _Let's evaluate the performance_

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

mse_AR = mean_squared_error(test['traffic_volume'], test['pred_ARMA'])

print(mse_AR)

# %% [markdown]
# > _This is an extremely high value, meaning our model is not good._

# %% [markdown]
# #### Let's Forecasting using SARIMA

# %% [markdown]
# > _As previously verified, our series exhibits seasonality, and for time series with seasonal patterns, the SARIMA model can be used._

# %%
df_SARIMA = df_sample.tail(10000)

# %%
df_SARIMA.head()
# Out:
#             date_time  traffic_volume
# 0 2017-08-09 00:00:00             676
# 1 2017-08-09 01:00:00             395
# 2 2017-08-09 02:00:00             306
# 3 2017-08-09 03:00:00             381
# 4 2017-08-09 04:00:00             949

# %% [markdown]
# > _Let's set our index using date_time column_

# %%
df_SARIMA.set_index('date_time', inplace=True)
df_SARIMA.head()
# Out:
#                      traffic_volume
# date_time
# 2017-08-09 00:00:00             676
# 2017-08-09 01:00:00             395
# 2017-08-09 02:00:00             306
# 2017-08-09 03:00:00             381
# 2017-08-09 04:00:00             949

# %% [markdown]
# > _Let's Resample our dataset to hourly frequency, and use interpolation for NAN values_

# %%
df_SARIMA_hourly = df_SARIMA.resample('h').interpolate()

# %%
df_SARIMA_hourly.head()
# Out:
#                      traffic_volume
# date_time
# 2017-08-09 00:00:00           676.0
# 2017-08-09 01:00:00           395.0
# 2017-08-09 02:00:00           306.0
# 2017-08-09 03:00:00           381.0
# 2017-08-09 04:00:00           949.0

# %%
df_SARIMA_hourly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10032 entries, 2017-08-09 00:00:00 to 2018-09-30 23:00:00
# Freq: H
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   traffic_volume  10032 non-null  float64
# dtypes: float64(1)
# memory usage: 156.8 KB

# %% [markdown]
# > _One way to identify seasonal patterns in time series is to use decomposition_

# %%
from statsmodels.tsa.seasonal import seasonal_decompose, STL

# Let's use a small sample 12 weeks for decomposition to see patterns
sample_SARIMA = df_SARIMA_hourly[['traffic_volume']][:24*7*12] # slice dataset using 24h*7days*12 = 12 weeks = 3months

decomposition = STL(sample_SARIMA['traffic_volume'], period=24).fit()

# %% [markdown]
# > _Let's look at the plots_

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=4, ncols=1, sharex=True, figsize=(10,8))

ax1.plot(decomposition.observed)
ax1.set_ylabel('Observed')

ax2.plot(decomposition.trend)
ax2.set_ylabel('Trend')

ax3.plot(decomposition.seasonal)
ax3.set_ylabel('Seasonal')

ax4.plot(decomposition.resid)
ax4.set_ylabel('Residuals')

fig.autofmt_xdate()
plt.tight_layout()

# %% [markdown]
# >_In the plot that displays seasonality, we can see a repeating pattern. Let's check for stationarity again!_

# %%
result_adf = adfuller(df_SARIMA_hourly['traffic_volume'])

print(f'ADF statistic: {result_adf[0]}')
print(f'P-value: {result_adf[1]}')
# Out:
# ADF statistic: -12.146512335526486
# P-value: 1.606134653428764e-22

# %% [markdown]
# > _With that large negative ADF and a P-value smaller than 0.05, we can consider our series as stationary again. Therefore, there is no need to apply differencing._

# %% [markdown]
# >_Let's plot ACF and PACF_

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

plot_acf(sample_SARIMA, lags=72, ax=ax1, title='ACF') # 72 hours

plot_pacf(sample_SARIMA, lags=72, ax=ax2, title='PACF')

plt.tight_layout()

# %% [markdown]
# > _As before the ACF graph displayed a sinusoidal pattern, showing seasonality and the need for a seasonal model, like SARIMA or SARIMAX._

# %% [markdown]
# >_To find the smallest AIC value, which will indicate which parameters to use for our SARIMA(p,d,q)(P,D,Q)m model, we will use the __pmdarima__ library, which uses Grid Search to test various parameter combinations._

# %%
# TOOK 1:50m to estimation, let's get a sample smaller

import pmdarima as pm

#Let's use the sample we create(sample_SARIMA just 3 months) for faster estimation.
# For seasonality (m=24)
best_model = pm.auto_arima(sample_SARIMA, 
                            seasonal=True, m=24, 
                            stepwise=True, 
                            suppress_warnings=True, 
                            error_action="ignore", 
                            max_p=3, max_q=3, max_P=2, max_Q=2,
                            trace=True)
print(best_model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[24] intercept   : AIC=30506.672, Time=21.13 sec
#  ARIMA(0,0,0)(0,0,0)[24] intercept   : AIC=36446.475, Time=0.03 sec
#  ARIMA(1,0,0)(1,0,0)[24] intercept   : AIC=31021.083, Time=106.12 sec
#  ARIMA(0,0,1)(0,0,1)[24] intercept   : AIC=32772.295, Time=8.22 sec
#  ARIMA(0,0,0)(0,0,0)[24]             : AIC=39198.892, Time=0.02 sec
#  ARIMA(2,0,2)(0,0,1)[24] intercept   : AIC=30896.227, Time=10.82 sec
#  ARIMA(2,0,2)(1,0,0)[24] intercept   : AIC=30518.399, Time=152.89 sec
#  ARIMA(2,0,2)(2,0,1)[24] intercept   : AIC=30703.364, Time=78.97 sec
#  ARIMA(2,0,2)(1,0,2)[24] intercept   : AIC=30709.088, Time=75.90 sec
#  ARIMA(2,0,2)(0,0,0)[24] intercept   : AIC=31494.768, Time=0.73 sec
#  ARIMA(2,0,2)(0,0,2)[24] intercept   : AIC=30689.910, Time=47.58 sec
#  ARIMA(2,0,2)(2,0,0)[24] intercept   : AIC=30494.174, Time=1389.84 sec
#  ARIMA(1,0,2)(2,0,0)[24] intercept   : AIC=30474.922, Time=897.05 sec
#  ARIMA(1,0,2)(1,0,0)[24] intercept   : AIC=30510.815, Time=142.39 sec
#  ARIMA(1,0,2)(2,0,1)[24] intercept   : AIC=inf, Time=63.45 sec
#  ARIMA(1,0,2)(1,0,1)[24] intercept   : AIC=30484.624, Time=14.21 sec
#  ARIMA(0,0,2)(2,0,0)[24] intercept   : AIC=32188.009, Time=839.44 sec
#  ARIMA(1,0,1)(2,0,0)[24] intercept   : AIC=30557.347, Time=793.10 sec
#  ARIMA(1,0,3)(2,0,0)[24] intercept   : AIC=30465.060, Time=925.98 sec
#  ARIMA(1,0,3)(1,0,0)[24] intercept   : AIC=30498.555, Time=106.13 sec
#  ARIMA(1,0,3)(2,0,1)[24] intercept   : AIC=inf, Time=69.75 sec
#  ARIMA(1,0,3)(1,0,1)[24] intercept   : AIC=30454.710, Time=18.13 sec
#  ARIMA(1,0,3)(0,0,1)[24] intercept   : AIC=30988.170, Time=10.74 sec
#  ARIMA(1,0,3)(1,0,2)[24] intercept   : AIC=30417.157, Time=73.14 sec
#  ARIMA(1,0,3)(0,0,2)[24] intercept   : AIC=30759.129, Time=36.91 sec
#  ARIMA(1,0,3)(2,0,2)[24] intercept   : AIC=inf, Time=80.50 sec
#  ARIMA(0,0,3)(1,0,2)[24] intercept   : AIC=inf, Time=68.04 sec
#  ARIMA(1,0,2)(1,0,2)[24] intercept   : AIC=30463.945, Time=62.60 sec
#  ARIMA(2,0,3)(1,0,2)[24] intercept   : AIC=inf, Time=74.57 sec
#  ARIMA(0,0,2)(1,0,2)[24] intercept   : AIC=31333.657, Time=61.99 sec
#  ARIMA(1,0,3)(1,0,2)[24]             : AIC=inf, Time=73.03 sec
#
# Best model:  ARIMA(1,0,3)(1,0,2)[24] intercept
# Total fit time: 6303.526 seconds
#                                         SARIMAX Results
# ===============================================================================================
# Dep. Variable:                                       y   No. Observations:                 2016
# Model:             SARIMAX(1, 0, 3)x(1, 0, [1, 2], 24)   Log Likelihood              -15199.579
# Date:                                 Fri, 16 Jan 2026   AIC                          30417.157
# Time:                                         15:28:10   BIC                          30467.637
# Sample:                                     08-09-2017   HQIC                         30435.685
#                                           - 10-31-2017
# Covariance Type:                                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    442.7604     53.812      8.228      0.000     337.290     548.231
# ar.L1          0.3044      0.043      7.025      0.000       0.219       0.389
# ma.L1          1.0062      0.041     24.373      0.000       0.925       1.087
# ma.L2          0.6854      0.050     13.787      0.000       0.588       0.783
# ma.L3          0.2926      0.032      9.115      0.000       0.230       0.356
# ar.S.L24       0.8458      0.015     55.798      0.000       0.816       0.876
# ma.S.L24      -0.2866      0.027    -10.439      0.000      -0.340      -0.233
# ma.S.L48      -0.1377      0.023     -5.933      0.000      -0.183      -0.092
# sigma2      2.042e+05   5366.512     38.058      0.000    1.94e+05    2.15e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.38   Jarque-Bera (JB):               444.56
# Prob(Q):                              0.12   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.11   Skew:                             0.07
# Prob(H) (two-sided):                  0.18   Kurtosis:                         5.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# > _Best model:  ARIMA(1,0,3)(1,0,2, 24)_
